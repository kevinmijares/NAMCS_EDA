# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd






df = pd.read_excel("namcs/namcs2019_sas.xlsx")
df.isna().sum()
# df = df.dropna(axis='columns', how ='all')
df.describe()
# Out:
#         Unnamed: 0       VMONTH        VDAYR          AGE         AGER  \
# count  8250.000000  8250.000000  8250.000000  8250.000000  8250.000000
# mean   4124.500000     6.273455     3.696970    51.470182     3.923030
# std    2381.714194     3.418679     1.385131    24.365268     1.516312
# min       0.000000     1.000000     2.000000     0.000000     1.000000
# 25%    2062.250000     3.000000     2.000000    34.000000     3.000000
# 50%    4124.500000     6.000000     3.000000    57.000000     4.000000
# 75%    6186.750000     9.000000     5.000000    71.000000     5.000000
# max    8249.000000    12.000000     7.000000    94.000000     6.000000
#
#            AGEDAYS          SEX     PREGNANT       GESTWK        ETHUN  ...  \
# count  8250.000000  8250.000000  8250.000000  8250.000000  8250.000000  ...
# mean     -3.270182     1.441333    -5.079515    -7.433576    -0.728485  ...
# std      28.974158     0.496576     4.423236     4.956595     4.656875  ...
# ...

# %%
df.shape
# Out:
# (8250, 864)
